# %%
from google.colab import auth
from google.cloud import bigquery
import pandas as pd

auth.authenticate_user()
project_id = "proud-woods-408708" # Ini project ID
client = bigquery.Client(project=project_id)

# %%
query = """SELECT * FROM bigquery-public-data.austin_bikeshare.bikeshare_trips"""
# Set up the query
query_job = client.query(query).to_dataframe()
query_job
# Out:
#           trip_id       subscriber_type bike_id bike_type  \
# 0         4098761  24 Hour Walk Up Pass     362   classic
# 1         4093022  24 Hour Walk Up Pass     282   classic
# 2         3988274  24 Hour Walk Up Pass     232   classic
# 3         3988069  24 Hour Walk Up Pass     140   classic
# 4         3961528              Local365     852   classic
# ...           ...                   ...     ...       ...
# 2112258  31870928    Student Membership   19955  electric
# 2112259  31790075    Student Membership   16936  electric
# 2112260  31880417       Pay-as-you-ride     576   classic
# 2112261  31945847    Student Membership   17850  electric
# 2112262  31957566    Student Membership   19235  electric
#
#                        start_time  start_station_id        start_station_name  \
# 0       2015-03-12 22:19:11+00:00              2546  ACC - West & 12th Street
# 1       2015-03-12 14:30:12+00:00              2545   ACC - Rio Grande & 12th
# 2       2015-02-21 21:32:12+00:00              2546  ACC - West & 12th Street
# 3       2015-02-21 19:01:06+00:00              <NA>     MapJam at Pan Am Park
# 4       2015-02-15 14:31:08+00:00              2545   ACC - Rio Grande & 12th
# ...                           ...               ...                       ...
# 2112258 2023-11-10 19:45:18+00:00              7189           28th/Rio Grande
# 2112259 2023-11-04 17:26:33+00:00              7189           28th/Rio Grande
# 2112260 2023-11-11 17:14:09+00:00              7189           28th/Rio Grande
# 2112261 2023-11-17 06:00:23+00:00              7189           28th/Rio Grande
# 2112262 2023-11-18 09:25:02+00:00              7189           28th/Rio Grande
#
#         end_station_id          end_station_name  duration_minutes
# 0                 2546  ACC - West & 12th Street                47
# 1                 2545   ACC - Rio Grande & 12th                33
# 2                 2546  ACC - West & 12th Street                45
# 3                 2568   East 11th/Victory Grill                18
# 4                 2712   Toomey Rd @ South Lamar                20
# ...                ...                       ...               ...
# 2112258           7189           28th/Rio Grande                 4
# 2112259           7189           28th/Rio Grande                 9
# 2112260           7189           28th/Rio Grande                 7
# 2112261           7189           28th/Rio Grande                56
# 2112262           7189           28th/Rio Grande                11
#
# [2112263 rows x 10 columns]

# %%
query = """SELECT
  table_catalog, table_schema, table_name, table_type,
  is_insertable_into, creation_time, ddl
FROM
  bigquery-public-data.austin_bikeshare.INFORMATION_SCHEMA.TABLES;"""
# Set up the query
query_job = client.query(query).to_dataframe()
query_job
# Out:
#           table_catalog      table_schema          table_name  table_type  \
# 0  bigquery-public-data  austin_bikeshare  bikeshare_stations  BASE TABLE
# 1  bigquery-public-data  austin_bikeshare     bikeshare_trips       CLONE
#
#   is_insertable_into                    creation_time  \
# 0                YES 2017-05-25 03:43:34.344000+00:00
# 1                YES 2023-07-17 16:41:33.433000+00:00
#
#                                                  ddl
# 0  CREATE TABLE `bigquery-public-data.austin_bike...
# 1  CREATE TABLE `bigquery-public-data.austin_bike...

# %%
query = """SELECT COUNT(*)
FROM
  bigquery-public-data.austin_bikeshare.INFORMATION_SCHEMA.TABLES;"""
# Set up the query
query_job = client.query(query).to_dataframe()
query_job
# Out:
#    f0_
# 0    2

# %%
query = """SELECT *
FROM
  bigquery-public-data.austin_bikeshare.INFORMATION_SCHEMA.COLUMNS
WHERE
  table_name = 'bikeshare_stations' AND data_type = "STRING";"""
# Set up the query
query_job = client.query(query).to_dataframe()
query_job
# Out:
#           table_catalog      table_schema          table_name     column_name  \
# 0  bigquery-public-data  austin_bikeshare  bikeshare_stations            name
# 1  bigquery-public-data  austin_bikeshare  bikeshare_stations          status
# 2  bigquery-public-data  austin_bikeshare  bikeshare_stations         address
# 3  bigquery-public-data  austin_bikeshare  bikeshare_stations  alternate_name
# 4  bigquery-public-data  austin_bikeshare  bikeshare_stations   property_type
# 5  bigquery-public-data  austin_bikeshare  bikeshare_stations      power_type
# 6  bigquery-public-data  austin_bikeshare  bikeshare_stations           notes
#
#    ordinal_position is_nullable data_type is_generated generation_expression  \
# 0                 2         YES    STRING        NEVER                  None
# 1                 3         YES    STRING        NEVER                  None
# 2                 4         YES    STRING        NEVER                  None
# 3                 5         YES    STRING        NEVER                  None
# 4                 7         YES    STRING        NEVER                  None
# 5                 9         YES    STRING        NEVER                  None
# 6                12         YES    STRING        NEVER                  None
#
#   is_stored is_hidden is_updatable is_system_defined is_partitioning_column  \
# 0      None        NO         None                NO                     NO
# 1      None        NO         None                NO                     NO
# 2      None        NO         None                NO                     NO
# 3      None        NO         None                NO                     NO
# 4      None        NO         None                NO                     NO
# 5      None        NO         None                NO                     NO
# 6      None        NO         None                NO                     NO
#
#    clustering_ordinal_position collation_name column_default rounding_mode
# 0                         <NA>           NULL           NULL          None
# 1                         <NA>           NULL           NULL          None
# 2                         <NA>           NULL           NULL          None
# 3                         <NA>           NULL           NULL          None
# 4                         <NA>           NULL           NULL          None
# 5                         <NA>           NULL           NULL          None
# 6                         <NA>           NULL           NULL          None

# %%
query = """SELECT COUNT(*)
FROM
  bigquery-public-data.austin_bikeshare.INFORMATION_SCHEMA.COLUMNS
WHERE
  table_name = 'bikeshare_stations' AND data_type = "STRING";"""
# Set up the query
query_job = client.query(query).to_dataframe()
query_job
# Out:
#    f0_
# 0    7

# %%
query = """SELECT *
FROM
  bigquery-public-data.austin_bikeshare.bikeshare_trips
WHERE
  bike_id IS NOT NULL AND duration_minutes > 1000"""
# Set up the query
query_job = client.query(query).to_dataframe()
query_job
# Out:
#        trip_id     subscriber_type bike_id bike_type  \
# 0     10342346             Walk Up     911   classic
# 1     10871188             Walk Up     193   classic
# 2     10871199             Walk Up     668   classic
# 3     11317281             Walk Up     479   classic
# 4     21605993            Local365    3212   classic
# ...        ...                 ...     ...       ...
# 3610  27496076  Student Membership   18909  electric
# 3611  27866791  Student Membership   19085  electric
# 3612  29705983             Local31   21789  electric
# 3613  29630616  Student Membership   19619  electric
# 3614  27357116  Student Membership   22196  electric
#
#                     start_time  start_station_id  \
# 0    2016-06-07 01:49:45+00:00              2568
# 1    2016-07-09 18:08:46+00:00              2562
# 2    2016-07-09 18:09:51+00:00              2562
# 3    2016-08-08 02:13:02+00:00              2561
# 4    2020-02-23 14:21:47+00:00              2540
# ...                        ...               ...
# 3610 2022-08-17 14:44:33+00:00              7188
# 3611 2022-09-17 12:56:13+00:00              7188
# 3612 2023-05-24 10:40:21+00:00              7189
# 3613 2023-05-15 13:11:21+00:00              7189
# 3614 2022-08-01 14:09:43+00:00              7189
#
#                                      start_station_name end_station_id  \
# 0                        East 11th St. at Victory Grill           2568
# 1                              San Jacinto & 8th Street           2562
# 2                              San Jacinto & 8th Street           2562
# 3     State Capitol Visitors Garage @ San Jacinto & ...           2561
# 4                                        17th/Guadalupe           2540
# ...                                                 ...            ...
# 3610                                         22nd/Pearl           7189
# 3611                                         22nd/Pearl           7189
# 3612                                    28th/Rio Grande           7189
# 3613                                    28th/Rio Grande           7189
# 3614                                           28th/Rio           7189
#
#                                        end_station_name  duration_minutes
# 0                        East 11th St. at Victory Grill              1405
# 1                              San Jacinto & 8th Street              1087
# 2                              San Jacinto & 8th Street              1150
# 3     State Capitol Visitors Garage @ San Jacinto & ...              1311
# 4                                        17th/Guadalupe              1186
# ...                                                 ...               ...
# 3610                                           28th/Rio              1084
# 3611                                           28th/Rio              1198
# 3612                     23rd/San Jacinto @ DKR Stadium              1451
# 3613                                    28th/Rio Grande              1196
# 3614                                           28th/Rio              1138
#
# [3615 rows x 10 columns]

# %%
query = """SELECT *
FROM
  bigquery-public-data.austin_bikeshare.bikeshare_trips
WHERE
  subscriber_type = 'Walk Up' AND end_station_name = 'Stolen'"""
# Set up the query
query_job = client.query(query).to_dataframe()
query_job
# Out:
#     trip_id subscriber_type bike_id bike_type                start_time  \
# 0  13555129         Walk Up     578   classic 2017-01-27 01:35:26+00:00
# 1  13564817         Walk Up     393   classic 2017-01-28 04:57:28+00:00
# 2  11712091         Walk Up     327   classic 2016-09-02 06:37:15+00:00
# 3  11714202         Walk Up     122   classic 2016-09-02 09:00:56+00:00
# 4  13857913         Walk Up     135   classic 2017-02-26 14:32:45+00:00
# 5  16898448         Walk Up    1857   classic 2018-03-18 22:51:20+00:00
# 6  16863172         Walk Up    1795   classic 2018-03-14 21:23:26+00:00
# 7  17151360         Walk Up    1899   classic 2018-04-21 15:29:10+00:00
#
#    start_station_id                                 start_station_name  \
# 0              2498            Convention Center / 4th St. @ MetroRail
# 1              2561  State Capitol Visitors Garage @ San Jacinto & ...
# 2              2565                               Trinity & 6th Street
# 3              2565                               Trinity & 6th Street
# 4              2566                      Pfluger Bridge @ W 2nd Street
# 5              2501                                        5th & Bowie
# 6              2542                                     Plaza Saltillo
# 7              2563                             Davis at Rainey Street
#
#   end_station_id end_station_name  duration_minutes
# 0           None           Stolen              5189
# 1           None           Stolen              4833
# 2           None           Stolen              6118
# 3           None           Stolen              5974
# 4           None           Stolen              1404
# 5           None           Stolen              3806
# 6           None           Stolen              2529
# 7           None           Stolen              4302
